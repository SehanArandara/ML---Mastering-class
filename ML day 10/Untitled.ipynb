# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
L1 = [1,2,3,4,5] 
L2 = [10,20,30,40,10]

# %%
plt.plot(L1,L2)
plt.show()    # return the chart

# %%
plt.plot(L1,L2)
plt.xlabel("Month")
plt.ylabel("Price ")
plt.title("Month over the price")
plt.show()

# %%
df = pd.read_csv("C:\\Users\\sdara\\Desktop\\Name.csv")
df
# Out:
#    Gender  Loan.Offered        Job  Work.Exp  Credit.Score  EMI.Ratio Status  \
# 0    Male             0  unskilled        14            86        3.0     No
# 1  Female             1    skilled        15            94        3.0     No
# 2    Male             0  unskilled        16            86        3.0     No
# 3  Female             1    skilled        13            94        3.0     No
# 4    Male             1    skilled        12            85        3.3     No
#
#   Credit.History  Own house   Purpose  Dependents
# 0           poor          1  personal           2
# 1           poor          1  personal           3
# 2           poor          1  personal           2
# 3           poor          1  personal           3
# 4           poor          1  personal           2

# %%
plt.scatter(df["Work.Exp"],df["Credit.Score"])
plt.xlabel("Work experience")
plt.ylabel("Credit Score")
plt.title("Work expreince against the Credit score ")
plt.show()
